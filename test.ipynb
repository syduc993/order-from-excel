# %% [markdown]
# # Test NhanhVN Product List API (v3.0/product/list)
#
# API này chính xác hơn /product/inventory và có inventory data trong response

# %%
import requests
import json
from pprint import pprint
import time
# Credentials từ .env
APP_ID = 76531  # VITE_NHANH_APP_ID
BUSINESS_ID = 209189  # VITE_NHANH_BUSINESS_ID
ACCESS_TOKEN = "JZu1Qvqaw9guvDMEvWMStxuuHoTUndZ5S9WNUKlKLb2Y81llfCReYMRfRL7DjRUWXos5DHxrasK8u2ZRxTH8xNgsmNU8YlMeSnVQgHTHEoT53qQjzkZz7SUoSc0Gj8xrCo87fzOx1fsYsOmFpdnYij4rYZYjvWFHpAz4wznikdpNs1JABwijty3lqH86jBGjXGaYZVC1x1VFWSi0mb7wIpp3LF5d3YAh9vg26p7QKie"   # VITE_NHANH_ACCESS_TOKEN

BASE_URL = "https://pos.open.nhanh.vn/v3.0"

print(f"✅ APP_ID: {APP_ID}")
print(f"✅ BUSINESS_ID: {BUSINESS_ID}")
print(f"✅ ACCESS_TOKEN: {ACCESS_TOKEN[:20]}...")
# Out:
# ✅ APP_ID: 76531
# ✅ BUSINESS_ID: 209189
# ✅ ACCESS_TOKEN: JZu1Qvqaw9guvDMEvWMS...

# %%
class NhanhVnService:
    def __init__(self, app_id, business_id, access_token):
        self.app_id = app_id
        self.business_id = business_id
        self.access_token = access_token
        self.base_url = "https://pos.open.nhanh.vn/v3.0"
        self.headers = {
            'Authorization': self.access_token,
            'Content-Type': 'application/json'
        }

    def _call_api(self, endpoint, payload):
        """Hàm chung để gọi API POST"""
        url = f"{self.base_url}{endpoint}?appId={self.app_id}&businessId={self.business_id}"
        try:
            response = requests.post(url, headers=self.headers, data=json.dumps(payload))
            response.raise_for_status() # Báo lỗi nếu HTTP status != 200
            return response.json()
        except requests.exceptions.RequestException as e:
            print(f"[Lỗi kết nối] {e}")
            return None

    def get_all_active_categories(self):
        """Lấy toàn bộ danh mục đang hoạt động (status=1)"""
        print("--- Đang lấy danh sách danh mục ---")
        endpoint = "/product/category"
        all_categories = []
        next_page = None

        while True:
            payload = {
                "filters": {
                    "status": 1  # Chỉ lấy danh mục Active
                },
                "paginator": {
                    "size": 50 # Tối ưu tốc độ
                }
            }
            
            # Nếu có trang tiếp theo, thêm vào payload
            if next_page:
                payload["paginator"]["next"] = next_page

            data = self._call_api(endpoint, payload)
            
            if not data or data.get('code') != 1:
                print(f"Lỗi lấy danh mục: {data.get('messages') if data else 'Unknown'}")
                break

            items = data.get('data', [])
            all_categories.extend(items)
            print(f"Đã tải {len(items)} danh mục...")

            # Kiểm tra phân trang
            paginator_resp = data.get('paginator', {})
            next_page = paginator_resp.get('next')
            
            # Nếu không còn trang sau hoặc next rỗng thì dừng
            if not next_page:
                break
            
        print(f"-> Tổng cộng: {len(all_categories)} danh mục.")
        return all_categories

    def get_inventory_by_category(self, category_id, category_name):
        """Lấy tồn kho theo ID danh mục"""
        print(f"--- Đang lấy tồn kho cho danh mục: {category_name} (ID: {category_id}) ---")
        endpoint = "/product/inventory"
        all_products = []
        next_page = None

        while True:
            payload = {
                "filters": {
                    "categoryId": category_id # Filter theo danh mục
                },
                "paginator": {
                    "size": 50
                }
            }

            if next_page:
                payload["paginator"]["next"] = next_page

            data = self._call_api(endpoint, payload)

            if not data or data.get('code') != 1:
                # Có thể danh mục này không có sản phẩm nào, hoặc lỗi
                break

            items = data.get('data', [])
            all_products.extend(items)

            paginator_resp = data.get('paginator', {})
            next_page = paginator_resp.get('next')

            if not next_page:
                break
        
        print(f"-> Tìm thấy {len(all_products)} sản phẩm trong danh mục '{category_name}'.")
        return all_products

# --- CHẠY THỬ ---
if __name__ == "__main__":
    # CẤU HÌNH THÔNG TIN CỦA BẠN
    APP_ID = 76531  # VITE_NHANH_APP_ID
    BUSINESS_ID = 209189  # VITE_NHANH_BUSINESS_ID
    ACCESS_TOKEN = "JZu1Qvqaw9guvDMEvWMStxuuHoTUndZ5S9WNUKlKLb2Y81llfCReYMRfRL7DjRUWXos5DHxrasK8u2ZRxTH8xNgsmNU8YlMeSnVQgHTHEoT53qQjzkZz7SUoSc0Gj8xrCo87fzOx1fsYsOmFpdnYij4rYZYjvWFHpAz4wznikdpNs1JABwijty3lqH86jBGjXGaYZVC1x1VFWSi0mb7wIpp3LF5d3YAh9vg26p7QKie"   # VITE_NHANH_ACCESS_TOKEN


    service = NhanhVnService(APP_ID, BUSINESS_ID, ACCESS_TOKEN)

    # 1. Lấy danh sách danh mục trước
    categories = service.get_all_active_categories()

    # 2. Duyệt qua từng danh mục để lấy tồn kho
    full_inventory_data = {} # Dictionary lưu kết quả: { "Tên danh mục": [Danh sách sản phẩm] }

    for cat in categories:
        cat_id = cat.get('id')
        cat_name = cat.get('name')
        
        # Gọi hàm lấy tồn kho
        products = service.get_inventory_by_category(cat_id, cat_name)
        
        if products:
            full_inventory_data[cat_name] = products
            
        # Nên sleep nhẹ 1 chút để tránh bị chặn rate limit nếu dữ liệu quá lớn
        # time.sleep(0.5) 

    # In thử kết quả của 1 danh mục đầu tiên để kiểm tra
    if full_inventory_data:
        first_cat = list(full_inventory_data.keys())[0]
        print(f"\nVí dụ dữ liệu tồn kho của danh mục '{first_cat}':")
        print(json.dumps(full_inventory_data[first_cat][:2], indent=2, ensure_ascii=False)) # In 2 sp đầu
    else:
        print("\nKhông tìm thấy dữ liệu tồn kho nào.")
# Out:
# --- Đang lấy danh sách danh mục ---
# Đã tải 34 danh mục...
# Đã tải 0 danh mục...
# -> Tổng cộng: 34 danh mục.
# --- Đang lấy tồn kho cho danh mục: Quần Gió (ID: 36) ---
# -> Tìm thấy 3 sản phẩm trong danh mục 'Quần Gió'.
# --- Đang lấy tồn kho cho danh mục: Ba lô (ID: 34) ---
# -> Tìm thấy 2 sản phẩm trong danh mục 'Ba lô'.
# --- Đang lấy tồn kho cho danh mục: Tất (ID: 33) ---
# -> Tìm thấy 7 sản phẩm trong danh mục 'Tất'.
# --- Đang lấy tồn kho cho danh mục: Quần Nỉ Dài (ID: 32) ---
# -> Tìm thấy 12 sản phẩm trong danh mục 'Quần Nỉ Dài'.
# --- Đang lấy tồn kho cho danh mục: Quần Lót (ID: 31) ---
# -> Tìm thấy 6 sản phẩm trong danh mục 'Quần Lót'.
# --- Đang lấy tồn kho cho danh mục: Quần Kaki (ID: 30) ---
# -> Tìm thấy 9 sản phẩm trong danh mục 'Quần Kaki'.
# --- Đang lấy tồn kho cho danh mục: Quần jogger (ID: 29) ---
# -> Tìm thấy 2 sản phẩm trong danh mục 'Quần jogger'.
# --- Đang lấy tồn kho cho danh mục: Mũ (ID: 28) ---
# -> Tìm thấy 4 sản phẩm trong danh mục 'Mũ'.
# --- Đang lấy tồn kho cho danh mục: Thắt lưng (ID: 26) ---
# -> Tìm thấy 8 sản phẩm trong danh mục 'Thắt lưng'.
# --- Đang lấy tồn kho cho danh mục: Giày Dép (ID: 25) ---
# -> Tìm thấy 16 sản phẩm trong danh mục 'Giày Dép'.
# --- Đang lấy tồn kho cho danh mục: Áo phao (ID: 24) ---
# -> Tìm thấy 1 sản phẩm trong danh mục 'Áo phao'.
# --- Đang lấy tồn kho cho danh mục: Áo Jacket (ID: 23) ---
# -> Tìm thấy 1 sản phẩm trong danh mục 'Áo Jacket'.
# --- Đang lấy tồn kho cho danh mục: Áo blazer (ID: 22) ---
# -> Tìm thấy 2 sản phẩm trong danh mục 'Áo blazer'.
# --- Đang lấy tồn kho cho danh mục: Áo Len (ID: 21) ---
# -> Tìm thấy 29 sản phẩm trong danh mục 'Áo Len'.
# --- Đang lấy tồn kho cho danh mục: Áo Gió (ID: 20) ---
# -> Tìm thấy 3 sản phẩm trong danh mục 'Áo Gió'.
# --- Đang lấy tồn kho cho danh mục: Áo cardigan (ID: 19) ---
# -> Tìm thấy 28 sản phẩm trong danh mục 'Áo cardigan'.
# --- Đang lấy tồn kho cho danh mục: Áo Nỉ  (ID: 18) ---
# -> Tìm thấy 54 sản phẩm trong danh mục 'Áo Nỉ '.
# --- Đang lấy tồn kho cho danh mục: Áo Măng Tô (ID: 17) ---
# -> Tìm thấy 2 sản phẩm trong danh mục 'Áo Măng Tô'.
# --- Đang lấy tồn kho cho danh mục: Áo Jean (ID: 16) ---
# -> Tìm thấy 2 sản phẩm trong danh mục 'Áo Jean'.
# --- Đang lấy tồn kho cho danh mục: Áo Hoodie (ID: 15) ---
# -> Tìm thấy 3 sản phẩm trong danh mục 'Áo Hoodie'.
# --- Đang lấy tồn kho cho danh mục: Áo giữ nhiệt (ID: 14) ---
# -> Tìm thấy 1 sản phẩm trong danh mục 'Áo giữ nhiệt'.
# --- Đang lấy tồn kho cho danh mục: Áo Da (ID: 13) ---
# -> Tìm thấy 1 sản phẩm trong danh mục 'Áo Da'.
# --- Đang lấy tồn kho cho danh mục: Áo khoác (ID: 12) ---
# -> Tìm thấy 39 sản phẩm trong danh mục 'Áo khoác'.
# --- Đang lấy tồn kho cho danh mục: Quần nỉ (ID: 11) ---
# -> Tìm thấy 14 sản phẩm trong danh mục 'Quần nỉ'.
# --- Đang lấy tồn kho cho danh mục: Áo sơ mi ngắn tay (ID: 10) ---
# -> Tìm thấy 7 sản phẩm trong danh mục 'Áo sơ mi ngắn tay'.
# --- Đang lấy tồn kho cho danh mục: Áo Tank Top (ID: 9) ---
# -> Tìm thấy 10 sản phẩm trong danh mục 'Áo Tank Top'.
# --- Đang lấy tồn kho cho danh mục: Quần Jeans (ID: 8) ---
# -> Tìm thấy 40 sản phẩm trong danh mục 'Quần Jeans'.
# --- Đang lấy tồn kho cho danh mục: Quần Âu (ID: 7) ---
# -> Tìm thấy 36 sản phẩm trong danh mục 'Quần Âu'.
# --- Đang lấy tồn kho cho danh mục: Quần Short (ID: 6) ---
# -> Tìm thấy 45 sản phẩm trong danh mục 'Quần Short'.
# --- Đang lấy tồn kho cho danh mục: Bộ Thể Thao Hè (ID: 5) ---
# -> Tìm thấy 24 sản phẩm trong danh mục 'Bộ Thể Thao Hè'.
# --- Đang lấy tồn kho cho danh mục: Túi (ID: 4) ---
# -> Tìm thấy 7 sản phẩm trong danh mục 'Túi'.
# --- Đang lấy tồn kho cho danh mục: Áo Sơ Mi Dài Tay (ID: 3) ---
# -> Tìm thấy 56 sản phẩm trong danh mục 'Áo Sơ Mi Dài Tay'.
# --- Đang lấy tồn kho cho danh mục: Áo PoLo (ID: 2) ---
# -> Tìm thấy 48 sản phẩm trong danh mục 'Áo PoLo'.
# --- Đang lấy tồn kho cho danh mục: Áo Phông (ID: 1) ---
# -> Tìm thấy 86 sản phẩm trong danh mục 'Áo Phông'.
#
# Ví dụ dữ liệu tồn kho của danh mục 'Quần Gió':
# [
#   {
#     "productId": 593,
#     "name": "Quần Gió Jogger Regular L.2.1845, nhãn hiệu Atino, size M-XXXL, mới 100%",
#     "prices": {
#       "price": 189000,
#       "import": 0,
#       "wholesale": 0,
#       "avgCost": 0
#     },
#     "inventory": {
#       "remain": 2,
#       "shipping": 0,
#       "damaged": 0,
#       "holding": 0,
#       "available": 2,
#       "warranty": {
#         "remain": 0,
#         "holding": 0
#       },
#       "depots": [
#         {
#           "id": 215639,
#           "remain": 2,
#           "shipping": 0,
#           "damaged": 0,
#           "holding": 0,
#           "available": 2,
#           "warranty": []
#         }
#       ]
#     }
#   },
#   {
#     "productId": 545,
#     "name": "Quần Gió 1856 dành cho nam, nhãn hiệu Atino, size từ 28-34, mới 100%",
#     "prices": {
#       "price": 209000,
#       "import": 0,
#       "wholesale": 0,
#       "avgCost": 0
#     },
#     "inventory": {
#       "remain": 5,
#       "shipping": 0,
#       "damaged": 0,
#       "holding": 0,
#       "available": 5,
#       "warranty": {
#         "remain": 0,
#         "holding": 0
#       },
#       "depots": [
#         {
#           "id": 215639,
#           "remain": 5,
#           "shipping": 0,
#           "damaged": 0,
#           "holding": 0,
#           "available": 5,
#           "warranty": []
#         }
#       ]
#     }
#   }
# ]
